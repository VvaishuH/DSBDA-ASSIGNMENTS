# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("Student_Performance.csv")

# %%
df
# Out:
#     Roll No  Subject1  Subject2  Subject3  Subject4  Subject5  Total  \
# 0         1      38.0      42.0      38.0      24.0      58.0    200
# 1         2      61.0      38.0      16.0      28.0      31.0    174
# 2         3      48.0      65.0      41.0      19.0      40.0    213
# 3         4       NaN      14.0      62.0     100.0      44.0    200
# 4         5       4.0       NaN      59.0      51.0      37.0    174
# 5         6      51.0      61.0      55.0      10.0      37.0    213
# 6         7      57.0      57.0      27.0      28.0      14.0    220
# 7         8      42.0      17.0       9.0      49.0      28.0    151
# 8         9     200.0      25.0      57.0      28.0       NaN    214
# 9        10      55.0      51.0      59.0       7.0      65.0    183
# 10       11      90.0      26.0      63.0      54.0      22.0    145
# 11       12      55.0      62.0      13.0       NaN       6.0    310
# 12       13      36.0      66.0      59.0       7.0      62.0    237
# 13       14      60.0      39.0      59.0      52.0      62.0    255
# 14       15      58.0       2.0      59.0      46.0      45.0    136
# 15       16      40.0      16.0      58.0      58.0      66.0    230
# 16       17      69.0      42.0      11.0      27.0      13.0    272
# 17       18      17.0      15.0      46.0       4.0      49.0    210
# 18       19      13.0      66.0       8.0      38.0      14.0    238
# 19       20      23.0       NaN       7.0     110.0      46.0    162
# 20       21      41.0      46.0      19.0      34.0      37.0    131
# 21       22      65.0      35.0      68.0      49.0      40.0    139
# 22       23      61.0      48.0      18.0      56.0       9.0    186
# 23       24      62.0      54.0      62.0      40.0      58.0    177
# 24       25     400.0      63.0       NaN      23.0       1.0    257
# 25       26      25.0      61.0      16.0       6.0      45.0    192
# 26       27      21.0      57.0      51.0      27.0      27.0    276
# 27       28      68.0       6.0      66.0      22.0      61.0    487
# 28       29      24.0      15.0      21.0      62.0      12.0    153
# 29       30      22.0      61.0      70.0       6.0     500.0    183
#
#     Percentage Result
# 0         40.0   PASS
# 1         34.8   FAIL
# 2         42.6   PASS
# 3         40.0   PASS
# 4         34.8   FAIL
# 5         42.6   PASS
# 6         44.0   PASS
# 7         30.2   FAIL
# 8         42.8   PASS
# 9         36.6   FAIL
# 10        29.0   FAIL
# 11        62.0   PASS
# 12        47.4   PASS
# 13        51.0   PASS
# 14        27.2   FAIL
# 15        46.0   PASS
# 16        54.4   PASS
# 17        42.0   PASS
# 18        47.6   PASS
# 19        32.4   FAIL
# 20        26.2   FAIL
# 21        27.8   FAIL
# 22        37.2   FAIL
# 23        35.4   FAIL
# 24        51.4   PASS
# 25        38.4   FAIL
# 26        55.2   PASS
# 27        97.4   PASS
# 28        30.6   FAIL
# 29        36.6   FAIL

# %%
df.shape
# Out:
# (30, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Roll No     30 non-null     int64
#  1   Subject1    29 non-null     float64
#  2   Subject2    28 non-null     float64
#  3   Subject3    29 non-null     float64
#  4   Subject4    29 non-null     float64
#  5   Subject5    29 non-null     float64
#  6   Total       30 non-null     int64
#  7   Percentage  30 non-null     float64
#  8   Result      30 non-null     object
# dtypes: float64(6), int64(2), object(1)
# memory usage: 2.2+ KB

# %%
df.describe(include="all")
# Out:
#           Roll No    Subject1   Subject2   Subject3    Subject4    Subject5  \
# count   30.000000   29.000000  28.000000  29.000000   29.000000   29.000000
# unique        NaN         NaN        NaN        NaN         NaN         NaN
# top           NaN         NaN        NaN        NaN         NaN         NaN
# freq          NaN         NaN        NaN        NaN         NaN         NaN
# mean    15.500000   62.275862  41.071429  41.275862   36.724138   52.724138
# std      8.803408   73.826000  20.517253  22.253245   25.855224   88.174703
# min      1.000000    4.000000   2.000000   7.000000    4.000000    1.000000
# 25%      8.250000   25.000000  23.000000  18.000000   22.000000   22.000000
# 50%     15.500000   51.000000  44.000000  51.000000   28.000000   40.000000
# 75%     22.750000   61.000000  61.000000  59.000000   51.000000   58.000000
# max     30.000000  400.000000  66.000000  70.000000  110.000000  500.000000
#
#              Total  Percentage Result
# count    30.000000   30.000000     30
# unique         NaN         NaN      2
# top            NaN         NaN   PASS
# freq           NaN         NaN     16
# mean    210.600000   42.120000    NaN
# std      68.846456   13.769291    NaN
# min     131.000000   26.200000    NaN
# 25%     174.000000   34.800000    NaN
# 50%     200.000000   40.000000    NaN
# 75%     235.250000   47.050000    NaN
# max     487.000000   97.400000    NaN

# %%
df.tail()
# Out:
#     Roll No  Subject1  Subject2  Subject3  Subject4  Subject5  Total  \
# 25       26      25.0      61.0      16.0       6.0      45.0    192
# 26       27      21.0      57.0      51.0      27.0      27.0    276
# 27       28      68.0       6.0      66.0      22.0      61.0    487
# 28       29      24.0      15.0      21.0      62.0      12.0    153
# 29       30      22.0      61.0      70.0       6.0     500.0    183
#
#     Percentage Result
# 25        38.4   FAIL
# 26        55.2   PASS
# 27        97.4   PASS
# 28        30.6   FAIL
# 29        36.6   FAIL

# %%
df.columns
# Out:
# Index(['Roll No', 'Subject1', 'Subject2', 'Subject3', 'Subject4', 'Subject5',
#        'Total', 'Percentage', 'Result'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Roll No         int64
# Subject1      float64
# Subject2      float64
# Subject3      float64
# Subject4      float64
# Subject5      float64
# Total           int64
# Percentage    float64
# Result         object
# dtype: object

# %%
df[0:5]
# Out:
#    Roll No  Subject1  Subject2  Subject3  Subject4  Subject5  Total  \
# 0        1      38.0      42.0      38.0      24.0      58.0    200
# 1        2      61.0      38.0      16.0      28.0      31.0    174
# 2        3      48.0      65.0      41.0      19.0      40.0    213
# 3        4       NaN      14.0      62.0     100.0      44.0    200
# 4        5       4.0       NaN      59.0      51.0      37.0    174
#
#    Percentage Result
# 0        40.0   PASS
# 1        34.8   FAIL
# 2        42.6   PASS
# 3        40.0   PASS
# 4        34.8   FAIL

# %%
df.loc[0:4]
# Out:
#    Roll No  Subject1  Subject2  Subject3  Subject4  Subject5  Total  \
# 0        1      38.0      42.0      38.0      24.0      58.0    200
# 1        2      61.0      38.0      16.0      28.0      31.0    174
# 2        3      48.0      65.0      41.0      19.0      40.0    213
# 3        4       NaN      14.0      62.0     100.0      44.0    200
# 4        5       4.0       NaN      59.0      51.0      37.0    174
#
#    Percentage Result
# 0        40.0   PASS
# 1        34.8   FAIL
# 2        42.6   PASS
# 3        40.0   PASS
# 4        34.8   FAIL

# %%
df.loc[0:2,'Subject1':'Subject5']
# Out:
#    Subject1  Subject2  Subject3  Subject4  Subject5
# 0      38.0      42.0      38.0      24.0      58.0
# 1      61.0      38.0      16.0      28.0      31.0
# 2      48.0      65.0      41.0      19.0      40.0

# %%
df.iloc[1:3]
# Out:
#    Roll No  Subject1  Subject2  Subject3  Subject4  Subject5  Total  \
# 1        2      61.0      38.0      16.0      28.0      31.0    174
# 2        3      48.0      65.0      41.0      19.0      40.0    213
#
#    Percentage Result
# 1        34.8   FAIL
# 2        42.6   PASS

# %%
df.isnull()
# Out:
#     Roll No  Subject1  Subject2  Subject3  Subject4  Subject5  Total  \
# 0     False     False     False     False     False     False  False
# 1     False     False     False     False     False     False  False
# 2     False     False     False     False     False     False  False
# 3     False      True     False     False     False     False  False
# 4     False     False      True     False     False     False  False
# 5     False     False     False     False     False     False  False
# 6     False     False     False     False     False     False  False
# 7     False     False     False     False     False     False  False
# 8     False     False     False     False     False      True  False
# 9     False     False     False     False     False     False  False
# 10    False     False     False     False     False     False  False
# 11    False     False     False     False      True     False  False
# 12    False     False     False     False     False     False  False
# 13    False     False     False     False     False     False  False
# 14    False     False     False     False     False     False  False
# 15    False     False     False     False     False     False  False
# 16    False     False     False     False     False     False  False
# 17    False     False     False     False     False     False  False
# 18    False     False     False     False     False     False  False
# 19    False     False      True     False     False     False  False
# 20    False     False     False     False     False     False  False
# 21    False     False     False     False     False     False  False
# 22    False     False     False     False     False     False  False
# 23    False     False     False     False     False     False  False
# 24    False     False     False      True     False     False  False
# 25    False     False     False     False     False     False  False
# 26    False     False     False     False     False     False  False
# 27    False     False     False     False     False     False  False
# 28    False     False     False     False     False     False  False
# 29    False     False     False     False     False     False  False
#
#     Percentage  Result
# 0        False   False
# 1        False   False
# 2        False   False
# 3        False   False
# 4        False   False
# 5        False   False
# 6        False   False
# 7        False   False
# 8        False   False
# 9        False   False
# 10       False   False
# 11       False   False
# 12       False   False
# 13       False   False
# 14       False   False
# 15       False   False
# 16       False   False
# 17       False   False
# 18       False   False
# 19       False   False
# 20       False   False
# 21       False   False
# 22       False   False
# 23       False   False
# 24       False   False
# 25       False   False
# 26       False   False
# 27       False   False
# 28       False   False
# 29       False   False

# %%
df.isna()
# Out:
#     Roll No  Subject1  Subject2  Subject3  Subject4  Subject5  Total  \
# 0     False     False     False     False     False     False  False
# 1     False     False     False     False     False     False  False
# 2     False     False     False     False     False     False  False
# 3     False      True     False     False     False     False  False
# 4     False     False      True     False     False     False  False
# 5     False     False     False     False     False     False  False
# 6     False     False     False     False     False     False  False
# 7     False     False     False     False     False     False  False
# 8     False     False     False     False     False      True  False
# 9     False     False     False     False     False     False  False
# 10    False     False     False     False     False     False  False
# 11    False     False     False     False      True     False  False
# 12    False     False     False     False     False     False  False
# 13    False     False     False     False     False     False  False
# 14    False     False     False     False     False     False  False
# 15    False     False     False     False     False     False  False
# 16    False     False     False     False     False     False  False
# 17    False     False     False     False     False     False  False
# 18    False     False     False     False     False     False  False
# 19    False     False      True     False     False     False  False
# 20    False     False     False     False     False     False  False
# 21    False     False     False     False     False     False  False
# 22    False     False     False     False     False     False  False
# 23    False     False     False     False     False     False  False
# 24    False     False     False      True     False     False  False
# 25    False     False     False     False     False     False  False
# 26    False     False     False     False     False     False  False
# 27    False     False     False     False     False     False  False
# 28    False     False     False     False     False     False  False
# 29    False     False     False     False     False     False  False
#
#     Percentage  Result
# 0        False   False
# 1        False   False
# 2        False   False
# 3        False   False
# 4        False   False
# 5        False   False
# 6        False   False
# 7        False   False
# 8        False   False
# 9        False   False
# 10       False   False
# 11       False   False
# 12       False   False
# 13       False   False
# 14       False   False
# 15       False   False
# 16       False   False
# 17       False   False
# 18       False   False
# 19       False   False
# 20       False   False
# 21       False   False
# 22       False   False
# 23       False   False
# 24       False   False
# 25       False   False
# 26       False   False
# 27       False   False
# 28       False   False
# 29       False   False

# %%
df.isnull().any()
# Out:
# Roll No       False
# Subject1       True
# Subject2       True
# Subject3       True
# Subject4       True
# Subject5       True
# Total         False
# Percentage    False
# Result        False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Roll No       0
# Subject1      1
# Subject2      2
# Subject3      1
# Subject4      1
# Subject5      1
# Total         0
# Percentage    0
# Result        0
# dtype: int64

# %%
df.Subject1.isnull().sum()
# Out:
# 1

# %%
cols_with_na = []
for col in df.columns:
  if df[col].isna().any():
    cols_with_na.append(col)
cols_with_na
# Out:
# ['Subject1', 'Subject2', 'Subject3', 'Subject4', 'Subject5']

# %%
df.replace(np.nan,value=0)
# Out:
#     Roll No  Subject1  Subject2  Subject3  Subject4  Subject5  Total  \
# 0         1      38.0      42.0      38.0      24.0      58.0    200
# 1         2      61.0      38.0      16.0      28.0      31.0    174
# 2         3      48.0      65.0      41.0      19.0      40.0    213
# 3         4       0.0      14.0      62.0     100.0      44.0    200
# 4         5       4.0       0.0      59.0      51.0      37.0    174
# 5         6      51.0      61.0      55.0      10.0      37.0    213
# 6         7      57.0      57.0      27.0      28.0      14.0    220
# 7         8      42.0      17.0       9.0      49.0      28.0    151
# 8         9     200.0      25.0      57.0      28.0       0.0    214
# 9        10      55.0      51.0      59.0       7.0      65.0    183
# 10       11      90.0      26.0      63.0      54.0      22.0    145
# 11       12      55.0      62.0      13.0       0.0       6.0    310
# 12       13      36.0      66.0      59.0       7.0      62.0    237
# 13       14      60.0      39.0      59.0      52.0      62.0    255
# 14       15      58.0       2.0      59.0      46.0      45.0    136
# 15       16      40.0      16.0      58.0      58.0      66.0    230
# 16       17      69.0      42.0      11.0      27.0      13.0    272
# 17       18      17.0      15.0      46.0       4.0      49.0    210
# 18       19      13.0      66.0       8.0      38.0      14.0    238
# 19       20      23.0       0.0       7.0     110.0      46.0    162
# 20       21      41.0      46.0      19.0      34.0      37.0    131
# 21       22      65.0      35.0      68.0      49.0      40.0    139
# 22       23      61.0      48.0      18.0      56.0       9.0    186
# 23       24      62.0      54.0      62.0      40.0      58.0    177
# 24       25     400.0      63.0       0.0      23.0       1.0    257
# 25       26      25.0      61.0      16.0       6.0      45.0    192
# 26       27      21.0      57.0      51.0      27.0      27.0    276
# 27       28      68.0       6.0      66.0      22.0      61.0    487
# 28       29      24.0      15.0      21.0      62.0      12.0    153
# 29       30      22.0      61.0      70.0       6.0     500.0    183
#
#     Percentage Result
# 0         40.0   PASS
# 1         34.8   FAIL
# 2         42.6   PASS
# 3         40.0   PASS
# 4         34.8   FAIL
# 5         42.6   PASS
# 6         44.0   PASS
# 7         30.2   FAIL
# 8         42.8   PASS
# 9         36.6   FAIL
# 10        29.0   FAIL
# 11        62.0   PASS
# 12        47.4   PASS
# 13        51.0   PASS
# 14        27.2   FAIL
# 15        46.0   PASS
# 16        54.4   PASS
# 17        42.0   PASS
# 18        47.6   PASS
# 19        32.4   FAIL
# 20        26.2   FAIL
# 21        27.8   FAIL
# 22        37.2   FAIL
# 23        35.4   FAIL
# 24        51.4   PASS
# 25        38.4   FAIL
# 26        55.2   PASS
# 27        97.4   PASS
# 28        30.6   FAIL
# 29        36.6   FAIL

# %%
df.fillna(1)
# Out:
#     Roll No  Subject1  Subject2  Subject3  Subject4  Subject5  Total  \
# 0         1      38.0      42.0      38.0      24.0      58.0    200
# 1         2      61.0      38.0      16.0      28.0      31.0    174
# 2         3      48.0      65.0      41.0      19.0      40.0    213
# 3         4       1.0      14.0      62.0     100.0      44.0    200
# 4         5       4.0       1.0      59.0      51.0      37.0    174
# 5         6      51.0      61.0      55.0      10.0      37.0    213
# 6         7      57.0      57.0      27.0      28.0      14.0    220
# 7         8      42.0      17.0       9.0      49.0      28.0    151
# 8         9     200.0      25.0      57.0      28.0       1.0    214
# 9        10      55.0      51.0      59.0       7.0      65.0    183
# 10       11      90.0      26.0      63.0      54.0      22.0    145
# 11       12      55.0      62.0      13.0       1.0       6.0    310
# 12       13      36.0      66.0      59.0       7.0      62.0    237
# 13       14      60.0      39.0      59.0      52.0      62.0    255
# 14       15      58.0       2.0      59.0      46.0      45.0    136
# 15       16      40.0      16.0      58.0      58.0      66.0    230
# 16       17      69.0      42.0      11.0      27.0      13.0    272
# 17       18      17.0      15.0      46.0       4.0      49.0    210
# 18       19      13.0      66.0       8.0      38.0      14.0    238
# 19       20      23.0       1.0       7.0     110.0      46.0    162
# 20       21      41.0      46.0      19.0      34.0      37.0    131
# 21       22      65.0      35.0      68.0      49.0      40.0    139
# 22       23      61.0      48.0      18.0      56.0       9.0    186
# 23       24      62.0      54.0      62.0      40.0      58.0    177
# 24       25     400.0      63.0       1.0      23.0       1.0    257
# 25       26      25.0      61.0      16.0       6.0      45.0    192
# 26       27      21.0      57.0      51.0      27.0      27.0    276
# 27       28      68.0       6.0      66.0      22.0      61.0    487
# 28       29      24.0      15.0      21.0      62.0      12.0    153
# 29       30      22.0      61.0      70.0       6.0     500.0    183
#
#     Percentage Result
# 0         40.0   PASS
# 1         34.8   FAIL
# 2         42.6   PASS
# 3         40.0   PASS
# 4         34.8   FAIL
# 5         42.6   PASS
# 6         44.0   PASS
# 7         30.2   FAIL
# 8         42.8   PASS
# 9         36.6   FAIL
# 10        29.0   FAIL
# 11        62.0   PASS
# 12        47.4   PASS
# 13        51.0   PASS
# 14        27.2   FAIL
# 15        46.0   PASS
# 16        54.4   PASS
# 17        42.0   PASS
# 18        47.6   PASS
# 19        32.4   FAIL
# 20        26.2   FAIL
# 21        27.8   FAIL
# 22        37.2   FAIL
# 23        35.4   FAIL
# 24        51.4   PASS
# 25        38.4   FAIL
# 26        55.2   PASS
# 27        97.4   PASS
# 28        30.6   FAIL
# 29        36.6   FAIL

# %%
df['Subject1']=df['Subject1'].fillna(df['Subject1'].mean())

# %%
df['Subject1']
# Out:
# 0      38.000000
# 1      61.000000
# 2      48.000000
# 3      62.275862
# 4       4.000000
# 5      51.000000
# 6      57.000000
# 7      42.000000
# 8     200.000000
# 9      55.000000
# 10     90.000000
# 11     55.000000
# 12     36.000000
# 13     60.000000
# 14     58.000000
# 15     40.000000
# 16     69.000000
# 17     17.000000
# 18     13.000000
# 19     23.000000
# 20     41.000000
# 21     65.000000
# 22     61.000000
# 23     62.000000
# 24    400.000000
# 25     25.000000
# 26     21.000000
# 27     68.000000
# 28     24.000000
# 29     22.000000
# Name: Subject1, dtype: float64

# %%
df['Subject1']=df['Subject1'].fillna(df['Subject1'].median())

# %%
df['Subject1']=df['Subject1'].fillna(df['Subject1'].mode())

# %%
df.head(10)
# Out:
#    Roll No    Subject1  Subject2  Subject3  Subject4  Subject5  Total  \
# 0        1   38.000000      42.0      38.0      24.0      58.0    200
# 1        2   61.000000      38.0      16.0      28.0      31.0    174
# 2        3   48.000000      65.0      41.0      19.0      40.0    213
# 3        4   62.275862      14.0      62.0     100.0      44.0    200
# 4        5    4.000000       NaN      59.0      51.0      37.0    174
# 5        6   51.000000      61.0      55.0      10.0      37.0    213
# 6        7   57.000000      57.0      27.0      28.0      14.0    220
# 7        8   42.000000      17.0       9.0      49.0      28.0    151
# 8        9  200.000000      25.0      57.0      28.0       NaN    214
# 9       10   55.000000      51.0      59.0       7.0      65.0    183
#
#    Percentage Result
# 0        40.0   PASS
# 1        34.8   FAIL
# 2        42.6   PASS
# 3        40.0   PASS
# 4        34.8   FAIL
# 5        42.6   PASS
# 6        44.0   PASS
# 7        30.2   FAIL
# 8        42.8   PASS
# 9        36.6   FAIL

# %%
df.dropna()
# Out:
#     Roll No   Subject1  Subject2  Subject3  Subject4  Subject5  Total  \
# 0         1  38.000000      42.0      38.0      24.0      58.0    200
# 1         2  61.000000      38.0      16.0      28.0      31.0    174
# 2         3  48.000000      65.0      41.0      19.0      40.0    213
# 3         4  62.275862      14.0      62.0     100.0      44.0    200
# 5         6  51.000000      61.0      55.0      10.0      37.0    213
# 6         7  57.000000      57.0      27.0      28.0      14.0    220
# 7         8  42.000000      17.0       9.0      49.0      28.0    151
# 9        10  55.000000      51.0      59.0       7.0      65.0    183
# 10       11  90.000000      26.0      63.0      54.0      22.0    145
# 12       13  36.000000      66.0      59.0       7.0      62.0    237
# 13       14  60.000000      39.0      59.0      52.0      62.0    255
# 14       15  58.000000       2.0      59.0      46.0      45.0    136
# 15       16  40.000000      16.0      58.0      58.0      66.0    230
# 16       17  69.000000      42.0      11.0      27.0      13.0    272
# 17       18  17.000000      15.0      46.0       4.0      49.0    210
# 18       19  13.000000      66.0       8.0      38.0      14.0    238
# 20       21  41.000000      46.0      19.0      34.0      37.0    131
# 21       22  65.000000      35.0      68.0      49.0      40.0    139
# 22       23  61.000000      48.0      18.0      56.0       9.0    186
# 23       24  62.000000      54.0      62.0      40.0      58.0    177
# 25       26  25.000000      61.0      16.0       6.0      45.0    192
# 26       27  21.000000      57.0      51.0      27.0      27.0    276
# 27       28  68.000000       6.0      66.0      22.0      61.0    487
# 28       29  24.000000      15.0      21.0      62.0      12.0    153
# 29       30  22.000000      61.0      70.0       6.0     500.0    183
#
#     Percentage Result
# 0         40.0   PASS
# 1         34.8   FAIL
# 2         42.6   PASS
# 3         40.0   PASS
# 5         42.6   PASS
# 6         44.0   PASS
# 7         30.2   FAIL
# 9         36.6   FAIL
# 10        29.0   FAIL
# 12        47.4   PASS
# 13        51.0   PASS
# 14        27.2   FAIL
# 15        46.0   PASS
# 16        54.4   PASS
# 17        42.0   PASS
# 18        47.6   PASS
# 20        26.2   FAIL
# 21        27.8   FAIL
# 22        37.2   FAIL
# 23        35.4   FAIL
# 25        38.4   FAIL
# 26        55.2   PASS
# 27        97.4   PASS
# 28        30.6   FAIL
# 29        36.6   FAIL

# %%
df.dropna(how="all")
# Out:
#     Roll No    Subject1  Subject2  Subject3  Subject4  Subject5  Total  \
# 0         1   38.000000      42.0      38.0      24.0      58.0    200
# 1         2   61.000000      38.0      16.0      28.0      31.0    174
# 2         3   48.000000      65.0      41.0      19.0      40.0    213
# 3         4   62.275862      14.0      62.0     100.0      44.0    200
# 4         5    4.000000       NaN      59.0      51.0      37.0    174
# 5         6   51.000000      61.0      55.0      10.0      37.0    213
# 6         7   57.000000      57.0      27.0      28.0      14.0    220
# 7         8   42.000000      17.0       9.0      49.0      28.0    151
# 8         9  200.000000      25.0      57.0      28.0       NaN    214
# 9        10   55.000000      51.0      59.0       7.0      65.0    183
# 10       11   90.000000      26.0      63.0      54.0      22.0    145
# 11       12   55.000000      62.0      13.0       NaN       6.0    310
# 12       13   36.000000      66.0      59.0       7.0      62.0    237
# 13       14   60.000000      39.0      59.0      52.0      62.0    255
# 14       15   58.000000       2.0      59.0      46.0      45.0    136
# 15       16   40.000000      16.0      58.0      58.0      66.0    230
# 16       17   69.000000      42.0      11.0      27.0      13.0    272
# 17       18   17.000000      15.0      46.0       4.0      49.0    210
# 18       19   13.000000      66.0       8.0      38.0      14.0    238
# 19       20   23.000000       NaN       7.0     110.0      46.0    162
# 20       21   41.000000      46.0      19.0      34.0      37.0    131
# 21       22   65.000000      35.0      68.0      49.0      40.0    139
# 22       23   61.000000      48.0      18.0      56.0       9.0    186
# 23       24   62.000000      54.0      62.0      40.0      58.0    177
# 24       25  400.000000      63.0       NaN      23.0       1.0    257
# 25       26   25.000000      61.0      16.0       6.0      45.0    192
# 26       27   21.000000      57.0      51.0      27.0      27.0    276
# 27       28   68.000000       6.0      66.0      22.0      61.0    487
# 28       29   24.000000      15.0      21.0      62.0      12.0    153
# 29       30   22.000000      61.0      70.0       6.0     500.0    183
#
#     Percentage Result
# 0         40.0   PASS
# 1         34.8   FAIL
# 2         42.6   PASS
# 3         40.0   PASS
# 4         34.8   FAIL
# 5         42.6   PASS
# 6         44.0   PASS
# 7         30.2   FAIL
# 8         42.8   PASS
# 9         36.6   FAIL
# 10        29.0   FAIL
# 11        62.0   PASS
# 12        47.4   PASS
# 13        51.0   PASS
# 14        27.2   FAIL
# 15        46.0   PASS
# 16        54.4   PASS
# 17        42.0   PASS
# 18        47.6   PASS
# 19        32.4   FAIL
# 20        26.2   FAIL
# 21        27.8   FAIL
# 22        37.2   FAIL
# 23        35.4   FAIL
# 24        51.4   PASS
# 25        38.4   FAIL
# 26        55.2   PASS
# 27        97.4   PASS
# 28        30.6   FAIL
# 29        36.6   FAIL

# %%
df.dropna(axis=1)
# Out:
#     Roll No    Subject1  Total  Percentage Result
# 0         1   38.000000    200        40.0   PASS
# 1         2   61.000000    174        34.8   FAIL
# 2         3   48.000000    213        42.6   PASS
# 3         4   62.275862    200        40.0   PASS
# 4         5    4.000000    174        34.8   FAIL
# 5         6   51.000000    213        42.6   PASS
# 6         7   57.000000    220        44.0   PASS
# 7         8   42.000000    151        30.2   FAIL
# 8         9  200.000000    214        42.8   PASS
# 9        10   55.000000    183        36.6   FAIL
# 10       11   90.000000    145        29.0   FAIL
# 11       12   55.000000    310        62.0   PASS
# 12       13   36.000000    237        47.4   PASS
# 13       14   60.000000    255        51.0   PASS
# 14       15   58.000000    136        27.2   FAIL
# 15       16   40.000000    230        46.0   PASS
# 16       17   69.000000    272        54.4   PASS
# 17       18   17.000000    210        42.0   PASS
# 18       19   13.000000    238        47.6   PASS
# 19       20   23.000000    162        32.4   FAIL
# 20       21   41.000000    131        26.2   FAIL
# 21       22   65.000000    139        27.8   FAIL
# 22       23   61.000000    186        37.2   FAIL
# 23       24   62.000000    177        35.4   FAIL
# 24       25  400.000000    257        51.4   PASS
# 25       26   25.000000    192        38.4   FAIL
# 26       27   21.000000    276        55.2   PASS
# 27       28   68.000000    487        97.4   PASS
# 28       29   24.000000    153        30.6   FAIL
# 29       30   22.000000    183        36.6   FAIL

# %%
df.dropna(axis=0,how='any',inplace=True)

# %%
df
# Out:
#     Roll No   Subject1  Subject2  Subject3  Subject4  Subject5  Total  \
# 0         1  38.000000      42.0      38.0      24.0      58.0    200
# 1         2  61.000000      38.0      16.0      28.0      31.0    174
# 2         3  48.000000      65.0      41.0      19.0      40.0    213
# 3         4  62.275862      14.0      62.0     100.0      44.0    200
# 5         6  51.000000      61.0      55.0      10.0      37.0    213
# 6         7  57.000000      57.0      27.0      28.0      14.0    220
# 7         8  42.000000      17.0       9.0      49.0      28.0    151
# 9        10  55.000000      51.0      59.0       7.0      65.0    183
# 10       11  90.000000      26.0      63.0      54.0      22.0    145
# 12       13  36.000000      66.0      59.0       7.0      62.0    237
# 13       14  60.000000      39.0      59.0      52.0      62.0    255
# 14       15  58.000000       2.0      59.0      46.0      45.0    136
# 15       16  40.000000      16.0      58.0      58.0      66.0    230
# 16       17  69.000000      42.0      11.0      27.0      13.0    272
# 17       18  17.000000      15.0      46.0       4.0      49.0    210
# 18       19  13.000000      66.0       8.0      38.0      14.0    238
# 20       21  41.000000      46.0      19.0      34.0      37.0    131
# 21       22  65.000000      35.0      68.0      49.0      40.0    139
# 22       23  61.000000      48.0      18.0      56.0       9.0    186
# 23       24  62.000000      54.0      62.0      40.0      58.0    177
# 25       26  25.000000      61.0      16.0       6.0      45.0    192
# 26       27  21.000000      57.0      51.0      27.0      27.0    276
# 27       28  68.000000       6.0      66.0      22.0      61.0    487
# 28       29  24.000000      15.0      21.0      62.0      12.0    153
# 29       30  22.000000      61.0      70.0       6.0     500.0    183
#
#     Percentage Result
# 0         40.0   PASS
# 1         34.8   FAIL
# 2         42.6   PASS
# 3         40.0   PASS
# 5         42.6   PASS
# 6         44.0   PASS
# 7         30.2   FAIL
# 9         36.6   FAIL
# 10        29.0   FAIL
# 12        47.4   PASS
# 13        51.0   PASS
# 14        27.2   FAIL
# 15        46.0   PASS
# 16        54.4   PASS
# 17        42.0   PASS
# 18        47.6   PASS
# 20        26.2   FAIL
# 21        27.8   FAIL
# 22        37.2   FAIL
# 23        35.4   FAIL
# 25        38.4   FAIL
# 26        55.2   PASS
# 27        97.4   PASS
# 28        30.6   FAIL
# 29        36.6   FAIL

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
sns.boxplot(x=df.Total)
# Out:
# <Axes: xlabel='Total'>

# %%
sns.boxplot(x=df.Percentage)
# Out:
# <Axes: xlabel='Percentage'>

# %%
sns.boxplot(x=df.Subject1)
# Out:
# <Axes: xlabel='Subject1'>

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (9, 6)
df_list = ['Roll No','Subject1','Total','Percentage']
fig, axes = plt.subplots(2, 2)
fig.set_dpi(120)
count=0
for r in range(2):
  for c in range(2):
    _ = df[df_list[count]].plot(kind = 'box', ax=axes[r,c])
    count+=1

# %%
Q1 = df['Percentage'].quantile(0.25)
Q3 = df['Percentage'].quantile(0.75)
IQR = Q3 - Q1
Lower_limit = Q1 - 1.5 * IQR
Upper_limit = Q3 + 1.5 * IQR
print(f'Q1 = {Q1}, Q3 = {Q3}, IQR = {IQR}, Lower_limit = {Lower_limit}, Upper_limit = {Upper_limit}')
# Out:
# Q1 = 34.8, Q3 = 46.0, IQR = 11.200000000000003, Lower_limit = 17.999999999999993, Upper_limit = 62.800000000000004

# %%
df[(df['Percentage'] < Lower_limit) | (df['Percentage'] > Upper_limit)]
# Out:
#     Roll No  Subject1  Subject2  Subject3  Subject4  Subject5  Total  \
# 27       28      68.0       6.0      66.0      22.0      61.0    487
#
#     Percentage Result
# 27        97.4   PASS

# %%
outliers=[]
for i in df.Percentage:
    if i<Lower_limit or i>Upper_limit:
        outliers.append(i)
print("outliers are",outliers)
# Out:
# outliers are [97.4]

# %%
Upper_limit
# Out:
# 62.800000000000004

# %%
Lower_limit
# Out:
# 17.999999999999993

# %%
df[df.Percentage<Lower_limit].index
# Out:
# Int64Index([], dtype='int64')

# %%
df1=df.drop(df[df.Percentage<Lower_limit].index)

# %%
df1.shape
# Out:
# (25, 9)

# %%
df2=df[df.Percentage<Lower_limit]

# %%
df2
# Out:
# Empty DataFrame
# Columns: [Roll No, Subject1, Subject2, Subject3, Subject4, Subject5, Total, Percentage, Result]
# Index: []

# %%
sns.kdeplot(df.Percentage)
# Out:
# <Axes: xlabel='Percentage', ylabel='Density'>

# %%
sns.kdeplot(df1.Percentage)
# Out:
# <Axes: xlabel='Percentage', ylabel='Density'>

# %%
df.Percentage
# Out:
# 0     40.0
# 1     34.8
# 2     42.6
# 3     40.0
# 5     42.6
# 6     44.0
# 7     30.2
# 9     36.6
# 10    29.0
# 12    47.4
# 13    51.0
# 14    27.2
# 15    46.0
# 16    54.4
# 17    42.0
# 18    47.6
# 20    26.2
# 21    27.8
# 22    37.2
# 23    35.4
# 25    38.4
# 26    55.2
# 27    97.4
# 28    30.6
# 29    36.6
# Name: Percentage, dtype: float64

# %%
log_percentage=np.log(df.Percentage)

# %%
log_percentage
# Out:
# 0     3.688879
# 1     3.549617
# 2     3.751854
# 3     3.688879
# 5     3.751854
# 6     3.784190
# 7     3.407842
# 9     3.600048
# 10    3.367296
# 12    3.858622
# 13    3.931826
# 14    3.303217
# 15    3.828641
# 16    3.996364
# 17    3.737670
# 18    3.862833
# 20    3.265759
# 21    3.325036
# 22    3.616309
# 23    3.566712
# 25    3.648057
# 26    4.010963
# 27    4.578826
# 28    3.421000
# 29    3.600048
# Name: Percentage, dtype: float64

# %%
sns.kdeplot(log_percentage)
# Out:
# <Axes: xlabel='Percentage', ylabel='Density'>

# %%
df.skew()
# Out:
# <ipython-input-78-9e0b1e29546f>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# Roll No      -0.061535
# Subject1     -0.089576
# Subject2     -0.409039
# Subject3     -0.392248
# Subject4      0.819804
# Subject5      4.692571
# Total         2.585100
# Percentage    2.585100
# dtype: float64

# %%
sns.kdeplot(df.Subject4);

# %%
sns.kdeplot(df.Subject1);

# %%
sns.kdeplot(df.Subject2);

# %%
sns.kdeplot(df.Subject3);

# %%
sns.kdeplot(df.Subject5);

# %%
sns.kdeplot(df.Total);

# %%
sns.kdeplot(df.Percentage);
